# %% [markdown]
# #**1. Data Preparation:**

# %% [markdown]
# #First import the libraries and load the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-896cb96e-8b64-4608-b807-6b98269eb9e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-896cb96e-8b64-4608-b807-6b98269eb9e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel('heart_disease.xlsx',sheet_name='Heart_disease')
df
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch  exang  oldpeak        slope               thal  num
# ...

# %% [markdown]
# #**2. Exploratory Data Analysis (EDA):**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       908 non-null    int64
#  1   sex       908 non-null    object
#  2   cp        908 non-null    object
#  3   trestbps  908 non-null    int64
#  4   chol      908 non-null    int64
#  5   fbs       908 non-null    bool
#  6   restecg   908 non-null    object
#  7   thalch    908 non-null    int64
#  8   exang     908 non-null    object
#  9   oldpeak   846 non-null    float64
#  10  slope     908 non-null    object
#  11  thal      908 non-null    object
#  12  num       908 non-null    int64
# dtypes: bool(1), float64(1), int64(5), object(6)
# memory usage: 86.1+ KB

# %%
df.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalch       0
# exang        0
# oldpeak     62
# slope        0
# thal         0
# num          0
# dtype: int64

# %%
df.describe()
# Out:
#               age    trestbps        chol      thalch     oldpeak         num
# count  908.000000  908.000000  908.000000  908.000000  846.000000  908.000000
# mean    53.791850  133.430617  201.484581  135.957048    0.891253    1.008811
# std      9.158031   20.401608  112.097949   26.804929    1.093875    1.144436
# min     29.000000    0.000000    0.000000   60.000000   -2.600000    0.000000
# 25%     47.750000  120.000000  176.750000  118.000000    0.000000    0.000000
# 50%     54.000000  130.000000  224.000000  138.000000    0.500000    1.000000
# 75%     60.000000  144.000000  270.000000  156.000000    1.500000    2.000000
# max     77.000000  200.000000  603.000000  202.000000    6.200000    4.000000

# %%
df.hist(figsize=(10,8))
plt.show()

# %% [markdown]
# #Box Plot for outliter detection

# %%
df.boxplot(figsize=(10,8))
plt.show()

# %% [markdown]
# #Correlation Metrics

# %%
plt.figure(figsize=(10,8))
# Calculate correlation only on numeric columns

sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# #**3. Feature Engineering:**

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Handling Missing Values

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='median')

# %%
df['oldpeak']= imputer.fit_transform(df[['oldpeak']])

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalch      0
# exang       0
# oldpeak     0
# slope       0
# thal        0
# num         0
# dtype: int64

# %% [markdown]
# #Label Encoding

# %%
label_encoder=LabelEncoder()

# %%
df['cp_label']=label_encoder.fit_transform(df['cp'])
df['cp_label']
# Out:
# 0      3
# 1      1
# 2      0
# 3      3
# 4      0
#       ..
# 903    0
# 904    0
# 905    2
# 906    2
# 907    0
# Name: cp_label, Length: 908, dtype: int64

# %% [markdown]
# #One-Hot Encoding

# %%
df=pd.get_dummies(df,columns=['cp'],drop_first=True)

# %%
df.head()
# Out:
#    age   sex  trestbps  chol    fbs         restecg  thalch  exang  oldpeak  \
# 0   63  Male       145   233   True  lv hypertrophy     150  False      2.3
# 1   41  Male       135   203  False          normal     132  False      0.0
# 2   57  Male       140   192  False          normal     148  False      0.4
# 3   52  Male       118   186  False  lv hypertrophy     190  False      0.0
# 4   57  Male       110   201  False          normal     126   True      1.5
#
#          slope          thal  num  cp_label  cp_atypical angina  \
# 0  downsloping  fixed defect    0         3               False
# 1         flat  fixed defect    0         1                True
# 2         flat  fixed defect    0         0               False
# 3         flat  fixed defect    0         3               False
# 4         flat  fixed defect    0         0               False
#
#    cp_non-anginal  cp_typical angina
# 0           False               True
# 1           False              False
# ...

# %% [markdown]
# #Splitting Data into x and y

# %%
x=df.drop('cp_label',axis=1)
y=df['cp_label']

# %% [markdown]
# #**4. Decision Tree Classification:**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,roc_auc_score,f1_score,recall_score,precision_score

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# #Initalize the desicion tree classifier

# %%
x_train=pd.get_dummies(x_train)

# %%
x_test=pd.get_dummies(x_test)

# %%
df_classifier=DecisionTreeClassifier(random_state=42)

# %%
df_classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# predict on test data
y_pred=df_classifier.predict(x_test)

# %%
# Evalution metrics
accuracy=accuracy_score(y_test,y_pred)
print(f'Accuracy:{accuracy:.2f}')
# Out:
# Accuracy:1.00

# %%
precision = precision_score(y_test,y_pred,average='weighted')
print(f'Precision:{precision:.2f}')
# Out:
# Precision:1.00

# %%
recall = recall_score(y_test,y_pred,average='weighted')
print(f'Recall:{recall:.2f}')
# Out:
# Recall:1.00

# %%
f1 = f1_score(y_test,y_pred,average='weighted')
print(f'f1:{f1:.2f}')
# Out:
# f1:1.00

# %% [markdown]
# #**5. Hyperparameter Tuning:**

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #Hyperparameter Tuning

# %%
param_grid={
    'max_depth':[3,5,10,None],
    'min_samples_split':[2,5,10],
    'criterion':['gini','entropy']
}

# %%
grid_search=GridSearchCV(estimator=df_classifier,param_grid=param_grid,cv=5,scoring='accuracy')
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 10, None],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %% [markdown]
# #Best Parameters

# %%
print(f'Best Parameters:{grid_search.best_params_}')
# Out:
# Best Parameters:{'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 2}

# %% [markdown]
# #Evaluate with the best model

# %%
best_model = grid_search.best_estimator_
y_pred_best = best_model.predict(x_test)

# %%
print(f"Optimizied Accuracy:{accuracy_score(y_test,y_pred_best):.2f}")
# Out:
# Optimizied Accuracy:1.00

# %% [markdown]
# #**6. Model Evaluation and Visualiztion**

# %%
from sklearn import tree

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(best_model,feature_names=x.columns,filled=True,class_names=True)
plt.show()

# %% [markdown]
# #**Interview Questions:**

# %% [markdown]
# #1. What are some common hyperparameters of decision tree models and how do they affect the model's preformance?

# %% [markdown]
# max_depth :- Limits the depth of the tree to prevent overfitting
#
# min_sample_split :- The minimum number of samples required to split mode
#
# criterion :- Define the function to measure the quality of a split

# %% [markdown]
# #2. What is the difference between the Label encoding and One-Hot encoding?

# %% [markdown]
# Lebel Encoding :- A data transformation technique that assign a unique integer to each category in a categorical variable
#
# One-Hot Encoding :- Create a binary column for a each category ,avoiding the ordinary problem but incressing dimensionality
