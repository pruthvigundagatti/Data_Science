# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import metrics

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d8aedcd8-674d-450f-88e5-90e10e40f71b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d8aedcd8-674d-450f-88e5-90e10e40f71b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel('EastWestAirlines.xlsx', sheet_name='data')
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID#, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award?]
# Index: []

# %%
data.nunique()
# Out:
# ID#                  3999
# Balance              3904
# Qual_miles            164
# cc1_miles               5
# cc2_miles               3
# cc3_miles               5
# Bonus_miles          2734
# Bonus_trans            57
# Flight_miles_12mo     343
# Flight_trans_12        35
# Days_since_enroll    2820
# Award?                  2
# dtype: int64

# %%
data.drop(columns=['ID#'],inplace=True)

# %%
def minmax_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
scaled_data=minmax_func(data)
scaled_data
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#WCSS (Within Cluster Sum of Squares)
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

print(wcss)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS (Within Cluster Sum of Squares)')
plt.show()
# Out:
# [1830.793212858416, 823.6756984125227, 635.2160678747765, 436.70885761932647, 409.84198454709735, 324.26256029101603, 311.9630560372351, 272.8276114425408, 245.24277703138262, 228.48943200048876]

# %%
kmeans_model=KMeans(n_clusters=6,random_state=40)
kmeans_model.fit(scaled_data)
# Out:
# KMeans(n_clusters=6, random_state=40)

# %%
kmeans_model.labels_
# Out:
# array([2, 2, 2, ..., 3, 4, 4], dtype=int32)

# %%
kmeans_df=scaled_data.copy()

# %%
kmeans_df['cluster_ID']=kmeans_model.labels_
kmeans_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
kmeans_df['cluster_ID'].value_counts()
# Out:
# cluster_ID
# 4    1032
# 2     868
# 1     673
# 0     618
# 5     428
# 3     380
# Name: count, dtype: int64

# %%
kmeans_df.groupby('cluster_ID').mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# cluster_ID
# 0           0.069389    0.006590   0.646036   0.000809   0.005663
# 1           0.048995    0.026054   0.039004   0.016345   0.002229
# 2           0.029282    0.008065   0.030530   0.009793   0.000288
# 3           0.040458    0.014807   0.634868   0.000000   0.003289
# 4           0.019414    0.008444   0.017684   0.008236   0.001696
# 5           0.084025    0.020441   0.812500   0.001168   0.009346
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# cluster_ID
# 0              0.119022     0.200384           0.007272         0.011846
# 1              0.033564     0.121825           0.033427         0.059407
# 2              0.013149     0.080391           0.007912         0.013738
# 3              0.125205     0.218880           0.018376         0.032324
# 4              0.012305     0.071784           0.006907         0.011390
# ...

# %%
metrics.silhouette_score(scaled_data,kmeans_model.labels_)
# Out:
# 0.4035297332431931

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
hc = AgglomerativeClustering(n_clusters=6, metric = 'euclidean', linkage = 'complete')
hc
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=6)

# %%
y_hc=hc.fit_predict(scaled_data)
y_hc
# Out:
# array([2, 2, 2, ..., 0, 2, 2])

# %%
hc_df=scaled_data.copy()
hc_df['cluster_ID']=y_hc
hc_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
hc_df['cluster_ID'].value_counts()
# Out:
# cluster_ID
# 2    2491
# 0    1144
# 1     325
# 4      31
# 5       4
# 3       4
# Name: count, dtype: int64

# %%
hc_df.groupby('cluster_ID').mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# cluster_ID
# 0           0.047027    0.022296   0.276224   0.004808   0.000219
# 1           0.092140    0.018719   0.915385   0.000000   0.015385
# 2           0.035171    0.007943   0.178242   0.000201   0.001505
# 3           0.077426    0.031127   0.375000   0.000000   0.000000
# 4           0.026698    0.002894   0.000000   0.741935   0.000000
# 5           0.037846    0.026507   0.062500   0.000000   0.812500
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# cluster_ID
# 0              0.064027     0.155960           0.024011         0.042205
# 1              0.267278     0.270340           0.033080         0.060319
# 2              0.038570     0.105757           0.007374         0.012331
# 3              0.248912     0.805233           0.647694         0.929245
# 4              0.055441     0.187547           0.014383         0.037127
# ...

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1, min_samples=100)
dbscan.fit(scaled_data)
# Out:
# DBSCAN(eps=1, min_samples=100)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
db_df=scaled_data.copy()
db_df['cluster_ID']=dbscan.labels_
db_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
db_df['cluster_ID'].value_counts()
# Out:
# cluster_ID
#  0    2518
#  1    1480
# -1       1
# Name: count, dtype: int64

# %%
metrics.silhouette_score(scaled_data,dbscan.labels_)
# Out:
# 0.5351606918177734
